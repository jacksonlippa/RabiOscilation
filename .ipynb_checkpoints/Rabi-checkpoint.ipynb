# %%
import numpy as np
import pandas as pd

# %%
#set initial conditions and true values
c10 = 1
c20 = 0
#rabi frequency
om = 2.0

# %%
#simulated noise
noise = np.random.normal(loc=0, scale=sigma, size=t.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #simulated noise
# ----> 2 noise = np.random.normal(loc=0, scale=sigma, size=t.shape)
#
# NameError: name 'sigma' is not defined
